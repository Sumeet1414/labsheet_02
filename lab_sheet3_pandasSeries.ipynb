# %%
import pandas as pd
a=[1,7.2,2]
myvar=pd.Series(a)
print(myvar)
# Out:
# 0    1.0
# 1    7.2
# 2    2.0
# dtype: float64

# %%
a=[1,7,2]
myvar = pd .Series(a,index=["x","y","z"])
print(myvar)
# Out:
# x    1
# y    7
# z    2
# dtype: int64

# %%
thisdict={
    "brand":"Ford",'model':"Mustang","year":1964
}
print(thisdict)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 1964}
